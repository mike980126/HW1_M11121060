# %% [markdown]
# # 匯入資料

# %% [markdown]
# ### 資料前處理

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("Dry_Bean_Dataset.xlsx")

# %%
mask1 = df["Area"] != "?"
mask2 = df["Perimeter"] != "?"
mask3 = df["MajorAxisLength"] != "?"
mask4 = df["MinorAxisLength"] != "?"
mask5 = df["AspectRation"] != "?"
mask6 = df["Eccentricity"] != "?"
mask7 = df["ConvexArea"] != "?"
mask8 = df["EquivDiameter"] != "?"
mask9 = df["Extent"] != "?"
mask10 = df["Solidity"] != "?"
mask11 = df["roundness"] != "?"
mask12 = df["Compactness"] != "?"
mask13 = df["ShapeFactor1"] != "?"
mask14 = df["ShapeFactor2"] != "?"
mask15 = df["ShapeFactor3"] != "?"
mask16 = df["ShapeFactor4"] != "?"
mask17 = df["Class"] != "?"

# %%
df2 = df[(mask1 & mask2 & mask3 & mask4 & mask5 & mask6 & mask7 & mask8 & mask9 & mask10 & mask11 & mask12 & mask13 & mask14 & mask15 & mask16 & mask17 )]

# %%
df2
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data_le=pd.DataFrame(df2)
data_le['Class'] = labelencoder.fit_transform(data_le['Class'])

# %%
df2
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653248  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#        Class
# 0          5
# 1          5
# 2          5
# 3          5
# 4          5
# ...      ...
# 13606      3
# 13607      3
# 13608      3
# 13609      3
# 13610      3
#
# [13611 rows x 17 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

y = df2['Class'].values
df2_1 = df2.drop(labels=['Area','AspectRation','Class'],axis=1)

df2_1v = df2_1.values

scaler = MinMaxScaler(feature_range=(0,1)).fit(df2_1)
df3 = scaler.transform(df2_1)


print('資料集 dbdpre 的平均值:',df2_1v.mean(axis=0))
print('資料集 dbdpre 的標準差:',df2_1v.std(axis=0))

print('標準化後 資料集 dbdpre 的平均值', df3.mean(axis=0))
print('標準化後 資料集 dbdpre 的標準差', df3.std(axis=0))

#引用來源 https://www.youtube.com/watch?v=P42GqxCXkY8
# Out:
# 資料集 dbdpre 的平均值: [8.55283459e+02 3.20141867e+02 2.02270714e+02 7.50894929e-01
#  5.37682002e+04 2.53064220e+02 7.49732787e-01 9.87142844e-01
#  8.73281831e-01 7.99863682e-01 6.56360851e-03 1.71594733e-03
#  6.43590181e-01 9.95063312e-01]
# 資料集 dbdpre 的標準差: [2.14281824e+02 8.56910379e+01 4.49684393e+01 9.19983835e-02
#  2.97738220e+04 5.91749462e+01 4.90845636e-02 4.66020796e-03
#  5.95177014e-02 6.17111960e-02 1.12795679e-03 5.95852967e-04
#  9.89925138e-02 4.36629734e-03]
# 標準化後 資料集 dbdpre 的平均值 [0.2263041  0.24590453 0.23619012 0.76818109 0.13638639 0.22497812
#  0.62537995 0.90011239 0.76569294 0.4594026  0.49335573 0.37144518
#  0.41325264 0.9102852 ]
# 標準化後 資料集 dbdpre 的標準差 [0.14670467 0.15432625 0.13316649 0.13285508 0.12273967 0.14499022
#  0.15788914 0.06178079 0.11878189 0.1779825  0.14700036 0.19216086
#  0.17538537 0.08389445]

# %%
x=df3
x
# Out:
# array([[0.05857388, 0.04426214, 0.15214169, ..., 0.83304879, 0.75099637,
#         0.98061988],
#        [0.07755673, 0.03047881, 0.17833666, ..., 0.96731548, 0.88498696,
#         0.97497943],
#        [0.06803484, 0.05263303, 0.1581899 , ..., 0.80094229, 0.7361995 ,
#         0.98719587],
#        ...,
#        [0.16060492, 0.17638393, 0.20337046, ..., 0.42701895, 0.4722397 ,
#         0.9430251 ],
#        [0.16365701, 0.17970258, 0.20066899, ..., 0.41532999, 0.45691893,
#         0.91334231],
#        [0.16944765, 0.20088207, 0.17676803, ..., 0.34689166, 0.36476185,
#         0.9701623 ]])

# %%
y
# Out:
# array([5, 5, 5, ..., 3, 3, 3])

# %% [markdown]
# # 區分訓練及測試資料&未設修剪的決策樹

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import tree
import pydot

# %%
#區分訓練資料及測試資料比例
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)
#trainning Decision Tree 未設alpha時
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
a = clf.score(x_train, y_train)
print(a)
b = clf.score(x_test, y_test)
print(b)
# Out:
# 1.0
# 0.8916636063165626

# %%
print(classification_report(y_test, clf.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       261
#            1       1.00      1.00      1.00       117
#            2       0.88      0.90      0.89       317
#            3       0.88      0.88      0.88       671
#            4       0.95      0.94      0.94       408
#            5       0.93      0.92      0.92       413
#            6       0.83      0.84      0.83       536
#
#     accuracy                           0.89      2723
#    macro avg       0.91      0.91      0.91      2723
# weighted avg       0.89      0.89      0.89      2723

# %%
#未修剪時之決策樹
tree.plot_tree(clf)
# Out:
# [Text(0.41146823169437485, 0.98, 'X[1] <= 0.174\ngini = 0.826\nsamples = 10888\nvalue = [1061, 405, 1313, 2875, 1520, 1614, 2100]'),
#  Text(0.19155085623449505, 0.94, 'X[10] <= 0.527\ngini = 0.537\nsamples = 4622\nvalue = [4, 0, 1, 2747, 10, 1485, 375]'),
#  Text(0.08664707724174474, 0.9, 'X[9] <= 0.612\ngini = 0.241\nsamples = 1639\nvalue = [4, 0, 1, 91, 1, 1420, 122]'),
#  Text(0.057564006840241815, 0.86, 'X[8] <= 0.872\ngini = 0.588\nsamples = 196\nvalue = [0, 0, 0, 57, 1, 30, 108]'),
#  Text(0.04104145090199668, 0.82, 'X[9] <= 0.596\ngini = 0.481\nsamples = 148\nvalue = [0, 0, 0, 35, 1, 12, 100]'),
#  Text(0.030443893157349647, 0.78, 'X[7] <= 0.937\ngini = 0.414\nsamples = 129\nvalue = [0, 0, 0, 30, 1, 4, 94]'),
#  Text(0.021195115489294057, 0.74, 'X[10] <= 0.526\ngini = 0.293\nsamples = 98\nvalue = [0, 0, 0, 15, 0, 2, 81]'),
#  Text(0.019653652544618126, 0.7, 'X[13] <= 0.987\ngini = 0.269\nsamples = 96\nvalue = [0, 0, 0, 13, 0, 2, 81]'),
#  Text(0.018112189599942194, 0.66, 'X[0] <= 0.189\ngini = 0.254\nsamples = 95\nvalue = [0, 0, 0, 13, 0, 1, 81]'),
#  Text(0.016570726655266262, 0.62, 'X[6] <= 0.848\ngini = 0.238\nsamples = 94\nvalue = [0, 0, 0, 13, 0, 0, 81]'),
#  Text(0.015029263710590332, 0.58, 'X[0] <= 0.151\ngini = 0.225\nsamples = 93\nvalue = [0, 0, 0, 12, 0, 0, 81]'),
#  Text(0.006165851778703726, 0.54, 'X[11] <= 0.477\ngini = 0.432\nsamples = 19\nvalue = [0, 0, 0, 6, 0, 0, 13]'),
#  Text(0.003082925889351863, 0.5, 'X[4] <= 0.084\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 0, 0, 1]'),
#  Text(0.0015414629446759314, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.004624388834027795, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.00924877766805559, 0.5, 'X[7] <= 0.889\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 0, 2, 0, 0, 12]'),
#  Text(0.007707314723379657, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.010790240612731521, 0.46, 'X[2] <= 0.193\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 1, 0, 0, 12]'),
#  Text(0.00924877766805559, 0.42, 'X[8] <= 0.856\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.007707314723379657, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.010790240612731521, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.012331703557407451, 0.42, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 0, 0, 10]'),
#  Text(0.02389267564247694, 0.54, 'X[13] <= 0.979\ngini = 0.149\nsamples = 74\nvalue = [0, 0, 0, 6, 0, 0, 68]'),
#  Text(0.02003901828078711, 0.5, 'X[9] <= 0.519\ngini = 0.109\nsamples = 69\nvalue = [0, 0, 0, 4, 0, 0, 65]'),
#  Text(0.016956092391435248, 0.46, 'X[2] <= 0.194\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.015414629446759314, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.01849755533611118, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.02312194417013897, 0.46, 'X[6] <= 0.601\ngini = 0.087\nsamples = 66\nvalue = [0, 0, 0, 3, 0, 0, 63]'),
#  Text(0.021580481225463043, 0.42, 'X[6] <= 0.599\ngini = 0.185\nsamples = 29\nvalue = [0, 0, 0, 3, 0, 0, 26]'),
#  Text(0.02003901828078711, 0.38, 'X[12] <= 0.528\ngini = 0.133\nsamples = 28\nvalue = [0, 0, 0, 2, 0, 0, 26]'),
#  Text(0.016956092391435248, 0.34, 'X[8] <= 0.847\ngini = 0.074\nsamples = 26\nvalue = [0, 0, 0, 1, 0, 0, 25]'),
#  Text(0.015414629446759314, 0.3, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 0, 0, 22]'),
#  Text(0.01849755533611118, 0.3, 'X[8] <= 0.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 3]'),
#  Text(0.016956092391435248, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.02003901828078711, 0.26, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.02312194417013897, 0.34, 'X[8] <= 0.807\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.021580481225463043, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.024663407114814902, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.02312194417013897, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.024663407114814902, 0.42, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 0, 0, 0, 0, 37]'),
#  Text(0.027746333004166766, 0.5, 'X[8] <= 0.833\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 0, 0, 3]'),
#  Text(0.026204870059490834, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.029287795948842697, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.018112189599942194, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.019653652544618126, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.021195115489294057, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.02273657843396999, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.03969267082540524, 0.74, 'X[8] <= 0.867\ngini = 0.585\nsamples = 31\nvalue = [0, 0, 0, 15, 1, 2, 13]'),
#  Text(0.033912184782870496, 0.7, 'X[10] <= 0.516\ngini = 0.566\nsamples = 24\nvalue = [0, 0, 0, 14, 1, 2, 7]'),
#  Text(0.030058527421180665, 0.66, 'X[6] <= 0.638\ngini = 0.663\nsamples = 14\nvalue = [0, 0, 0, 5, 1, 2, 6]'),
#  Text(0.0269756015318288, 0.62, 'X[13] <= 0.947\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 0, 5, 0, 1, 2]'),
#  Text(0.02543413858715287, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.028517064476504733, 0.58, 'X[5] <= 0.176\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 0, 1, 0]'),
#  Text(0.0269756015318288, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.030058527421180665, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.033141453310532525, 0.62, 'X[1] <= 0.17\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 0, 1, 1, 4]'),
#  Text(0.031599990365856596, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 0, 4]'),
#  Text(0.03468291625520846, 0.58, 'X[11] <= 0.438\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1, 0]'),
#  Text(0.033141453310532525, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.03622437919988439, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.03776584214456032, 0.66, 'X[13] <= 0.977\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 0, 0, 1]'),
#  Text(0.03622437919988439, 0.62, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0, 0]'),
#  Text(0.03930730508923625, 0.62, 'X[6] <= 0.699\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.03776584214456032, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.040848768033912186, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.04547315686793998, 0.7, 'X[1] <= 0.164\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 0, 0, 6]'),
#  Text(0.04393169392326405, 0.66, 'X[3] <= 0.703\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.042390230978588114, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.04547315686793998, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.04701461981261591, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 5]'),
#  Text(0.051639008646643704, 0.78, 'X[1] <= 0.162\ngini = 0.654\nsamples = 19\nvalue = [0, 0, 0, 5, 0, 8, 6]'),
#  Text(0.050097545701967776, 0.74, 'X[10] <= 0.497\ngini = 0.617\nsamples = 16\nvalue = [0, 0, 0, 5, 0, 8, 3]'),
#  Text(0.04855608275729184, 0.7, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 6, 0]'),
#  Text(0.051639008646643704, 0.7, 'X[6] <= 0.68\ngini = 0.62\nsamples = 10\nvalue = [0, 0, 0, 5, 0, 2, 3]'),
#  Text(0.050097545701967776, 0.66, 'X[7] <= 0.907\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 0, 5, 0, 0, 3]'),
#  Text(0.04855608275729184, 0.62, 'X[13] <= 0.973\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 3]'),
#  Text(0.04701461981261591, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.050097545701967776, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.051639008646643704, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.05318047159131964, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.05318047159131964, 0.74, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.07408656277848696, 0.82, 'X[0] <= 0.155\ngini = 0.622\nsamples = 48\nvalue = [0, 0, 0, 22, 0, 18, 8]'),
#  Text(0.06878778390616344, 0.78, 'X[7] <= 0.96\ngini = 0.584\nsamples = 39\nvalue = [0, 0, 0, 22, 0, 10, 7]'),
#  Text(0.06281461499554421, 0.74, 'X[13] <= 0.955\ngini = 0.644\nsamples = 29\nvalue = [0, 0, 0, 13, 0, 9, 7]'),
#  Text(0.05780486042534743, 0.7, 'X[4] <= 0.079\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 7, 0, 0, 2]'),
#  Text(0.0562633974806715, 0.66, 'X[6] <= 0.536\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.05472193453599557, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.05780486042534743, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.059346323370023366, 0.66, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0, 0]'),
#  Text(0.06782436956574099, 0.7, 'X[7] <= 0.947\ngini = 0.645\nsamples = 20\nvalue = [0, 0, 0, 6, 0, 9, 5]'),
#  Text(0.06397071220405116, 0.66, 'X[2] <= 0.207\ngini = 0.595\nsamples = 11\nvalue = [0, 0, 0, 6, 0, 2, 3]'),
#  Text(0.060887786314699294, 0.62, 'X[2] <= 0.192\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 3]'),
#  Text(0.059346323370023366, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.06242924925937523, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.06705363809340302, 0.62, 'X[5] <= 0.165\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 0, 2, 0]'),
#  Text(0.06551217514872709, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.06859510103807895, 0.58, 'X[5] <= 0.167\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 2, 0]'),
#  Text(0.06705363809340302, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.07013656398275488, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.07167802692743082, 0.66, 'X[8] <= 0.883\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 0, 0, 7, 2]'),
#  Text(0.07013656398275488, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.07321948987210675, 0.62, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 7, 0]'),
#  Text(0.07476095281678267, 0.74, 'X[7] <= 0.976\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 0, 1, 0]'),
#  Text(0.07321948987210675, 0.7, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0, 0]'),
#  Text(0.0763024157614586, 0.7, 'X[4] <= 0.087\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1, 0]'),
#  Text(0.07476095281678267, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.07784387870613454, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.07938534165081047, 0.78, 'X[13] <= 0.93\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 0, 0, 8, 1]'),
#  Text(0.07784387870613454, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.0809268045954864, 0.74, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 0, 8, 0]'),
#  Text(0.11573014764324767, 0.86, 'X[12] <= 0.613\ngini = 0.071\nsamples = 1443\nvalue = [4, 0, 1, 34, 0, 1390, 14]'),
#  Text(0.09576338543799225, 0.82, 'X[13] <= 0.941\ngini = 0.402\nsamples = 125\nvalue = [1, 0, 0, 20, 0, 94, 10]'),
#  Text(0.08709265637419013, 0.78, 'X[1] <= 0.14\ngini = 0.623\nsamples = 18\nvalue = [0, 0, 0, 5, 0, 4, 9]'),
#  Text(0.08400973048483827, 0.74, 'X[13] <= 0.908\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 0, 5, 0, 2, 1]'),
#  Text(0.08246826754016233, 0.7, 'X[8] <= 0.863\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 2, 1]'),
#  Text(0.0809268045954864, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.08400973048483827, 0.66, 'X[2] <= 0.205\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.08246826754016233, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.0855511934295142, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.0855511934295142, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.090175582263542, 0.74, 'X[6] <= 0.654\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 0, 0, 2, 8]'),
#  Text(0.08863411931886606, 0.7, 'X[7] <= 0.945\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 2, 1]'),
#  Text(0.08709265637419013, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.090175582263542, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.09171704520821793, 0.7, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 0, 7]'),
#  Text(0.10443411450179436, 0.78, 'X[7] <= 0.952\ngini = 0.273\nsamples = 107\nvalue = [1, 0, 0, 15, 0, 90, 1]'),
#  Text(0.10289265155711842, 0.74, 'X[0] <= 0.138\ngini = 0.448\nsamples = 55\nvalue = [1, 0, 0, 15, 0, 38, 1]'),
#  Text(0.09479997109756978, 0.7, 'X[13] <= 0.967\ngini = 0.494\nsamples = 18\nvalue = [0, 0, 0, 10, 0, 8, 0]'),
#  Text(0.09325850815289385, 0.66, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0, 0]'),
#  Text(0.09634143404224572, 0.66, 'X[13] <= 0.983\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 3, 0, 8, 0]'),
#  Text(0.09479997109756978, 0.62, 'X[6] <= 0.617\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 0, 3, 0]'),
#  Text(0.09325850815289385, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.09634143404224572, 0.58, 'X[13] <= 0.968\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 1, 0]'),
#  Text(0.09479997109756978, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.09788289698692165, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.09788289698692165, 0.62, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]'),
#  Text(0.11098533201666706, 0.7, 'X[8] <= 0.912\ngini = 0.323\nsamples = 37\nvalue = [1, 0, 0, 5, 0, 30, 1]'),
#  Text(0.1079024061273152, 0.66, 'X[6] <= 0.762\ngini = 0.263\nsamples = 34\nvalue = [1, 0, 0, 3, 0, 29, 1]'),
#  Text(0.10636094318263928, 0.62, 'X[0] <= 0.141\ngini = 0.222\nsamples = 33\nvalue = [1, 0, 0, 2, 0, 29, 1]'),
#  Text(0.10250728582094945, 0.58, 'X[7] <= 0.941\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 1, 1]'),
#  Text(0.10096582287627351, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.10404874876562538, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.1102146005443291, 0.58, 'X[0] <= 0.181\ngini = 0.179\nsamples = 31\nvalue = [1, 0, 0, 2, 0, 28, 0]'),
#  Text(0.10713167465497724, 0.54, 'X[6] <= 0.58\ngini = 0.074\nsamples = 26\nvalue = [0, 0, 0, 1, 0, 25, 0]'),
#  Text(0.10559021171030131, 0.5, 'X[6] <= 0.566\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 2, 0]'),
#  Text(0.10404874876562538, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.10713167465497724, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.10867313759965318, 0.5, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 0, 0, 23, 0]'),
#  Text(0.11329752643368096, 0.54, 'X[6] <= 0.684\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 0, 1, 0, 3, 0]'),
#  Text(0.11175606348900503, 0.5, 'X[13] <= 0.968\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0, 0]'),
#  Text(0.1102146005443291, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.11329752643368096, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.11483898937835689, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.10944386907199113, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.11406825790601893, 0.66, 'X[4] <= 0.083\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1, 0]'),
#  Text(0.112526794961343, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.11560972085069486, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.10597557744647029, 0.74, 'gini = 0.0\nsamples = 52\nvalue = [0, 0, 0, 0, 0, 52, 0]'),
#  Text(0.1356969098485031, 0.82, 'X[6] <= 0.878\ngini = 0.033\nsamples = 1318\nvalue = [3, 0, 1, 14, 0, 1296, 4]'),
#  Text(0.13415544690382716, 0.78, 'X[4] <= 0.124\ngini = 0.032\nsamples = 1317\nvalue = [3, 0, 1, 13, 0, 1296, 4]'),
#  Text(0.1274597172378911, 0.74, 'X[13] <= 0.889\ngini = 0.029\nsamples = 1313\nvalue = [1, 0, 1, 13, 0, 1294, 4]'),
#  Text(0.11869264674004673, 0.7, 'X[10] <= 0.479\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 0, 2, 0, 5, 1]'),
#  Text(0.11715118379537079, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]'),
#  Text(0.12023410968472266, 0.66, 'X[7] <= 0.875\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]'),
#  Text(0.11869264674004673, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.12177557262939859, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.13622678773573543, 0.7, 'X[12] <= 0.633\ngini = 0.024\nsamples = 1305\nvalue = [1, 0, 1, 11, 0, 1289, 3]'),
#  Text(0.12794142440810233, 0.66, 'X[9] <= 0.678\ngini = 0.192\nsamples = 85\nvalue = [0, 0, 0, 8, 0, 76, 1]'),
#  Text(0.12485849851875046, 0.62, 'X[0] <= 0.113\ngini = 0.142\nsamples = 79\nvalue = [0, 0, 0, 5, 0, 73, 1]'),
#  Text(0.12331703557407452, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.12639996146342639, 0.58, 'X[6] <= 0.797\ngini = 0.121\nsamples = 78\nvalue = [0, 0, 0, 4, 0, 73, 1]'),
#  Text(0.12485849851875046, 0.54, 'X[13] <= 0.945\ngini = 0.1\nsamples = 77\nvalue = [0, 0, 0, 3, 0, 73, 1]'),
#  Text(0.12100484115706062, 0.5, 'X[13] <= 0.94\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 2, 0, 5, 0]'),
#  Text(0.11946337821238469, 0.46, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]'),
#  Text(0.12254630410173656, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.12871215588044027, 0.5, 'X[8] <= 0.951\ngini = 0.056\nsamples = 70\nvalue = [0, 0, 0, 1, 0, 68, 1]'),
#  Text(0.12562922999108841, 0.46, 'X[7] <= 0.917\ngini = 0.029\nsamples = 68\nvalue = [0, 0, 0, 0, 0, 67, 1]'),
#  Text(0.12408776704641249, 0.42, 'X[8] <= 0.855\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 5, 1]'),
#  Text(0.12254630410173656, 0.38, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]'),
#  Text(0.12562922999108841, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.12717069293576436, 0.42, 'gini = 0.0\nsamples = 62\nvalue = [0, 0, 0, 0, 0, 62, 0]'),
#  Text(0.13179508176979216, 0.46, 'X[6] <= 0.681\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1, 0]'),
#  Text(0.1302536188251162, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.13333654471446807, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.12794142440810233, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.13102435029745418, 0.62, 'X[1] <= 0.127\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 0, 3, 0]'),
#  Text(0.12948288735277824, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.1325658132421301, 0.58, 'X[7] <= 0.973\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 3, 0]'),
#  Text(0.13102435029745418, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.13410727618680604, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.14451215106336857, 0.66, 'X[11] <= 0.528\ngini = 0.011\nsamples = 1220\nvalue = [1, 0, 1, 3, 0, 1213, 2]'),
#  Text(0.14027312796550975, 0.62, 'X[6] <= 0.669\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 1, 0, 0, 3, 0]'),
#  Text(0.13873166502083384, 0.58, 'X[10] <= 0.411\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0, 0]'),
#  Text(0.1371902020761579, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.14027312796550975, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.1418145909101857, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.14875117416122738, 0.62, 'X[13] <= 0.936\ngini = 0.008\nsamples = 1215\nvalue = [0, 0, 0, 3, 0, 1210, 2]'),
#  Text(0.14489751679953755, 0.58, 'X[13] <= 0.936\ngini = 0.169\nsamples = 33\nvalue = [0, 0, 0, 2, 0, 30, 1]'),
#  Text(0.14335605385486164, 0.54, 'X[2] <= 0.2\ngini = 0.117\nsamples = 32\nvalue = [0, 0, 0, 2, 0, 30, 0]'),
#  Text(0.1418145909101857, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.14489751679953755, 0.5, 'X[2] <= 0.226\ngini = 0.062\nsamples = 31\nvalue = [0, 0, 0, 1, 0, 30, 0]'),
#  Text(0.14335605385486164, 0.46, 'X[10] <= 0.481\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 0, 7, 0]'),
#  Text(0.1418145909101857, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.14489751679953755, 0.42, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 7, 0]'),
#  Text(0.1464389797442135, 0.46, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 0, 0, 0, 23, 0]'),
#  Text(0.1464389797442135, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.1526048315229172, 0.58, 'X[10] <= 0.526\ngini = 0.003\nsamples = 1182\nvalue = [0, 0, 0, 1, 0, 1180, 1]'),
#  Text(0.14952190563356535, 0.54, 'X[3] <= 0.593\ngini = 0.002\nsamples = 1176\nvalue = [0, 0, 0, 0, 0, 1175, 1]'),
#  Text(0.14798044268888944, 0.5, 'gini = 0.0\nsamples = 1117\nvalue = [0, 0, 0, 0, 0, 1117, 0]'),
#  Text(0.1510633685782413, 0.5, 'X[12] <= 0.648\ngini = 0.033\nsamples = 59\nvalue = [0, 0, 0, 0, 0, 58, 1]'),
#  Text(0.14952190563356535, 0.46, 'gini = 0.0\nsamples = 58\nvalue = [0, 0, 0, 0, 0, 58, 0]'),
#  Text(0.1526048315229172, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.1556877574122691, 0.54, 'X[13] <= 0.965\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 0, 5, 0]'),
#  Text(0.15414629446759315, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.157229220356945, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]'),
#  Text(0.14085117656976323, 0.74, 'X[8] <= 0.834\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 0, 0, 0, 2, 0]'),
#  Text(0.13930971362508732, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(0.14239263951443917, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.13723837279317902, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.29645463522724536, 0.9, 'X[0] <= 0.127\ngini = 0.2\nsamples = 2983\nvalue = [0, 0, 0, 2656, 9, 65, 253]'),
#  Text(0.22046532912642405, 0.86, 'X[9] <= 0.719\ngini = 0.087\nsamples = 2382\nvalue = [0, 0, 0, 2275, 6, 61, 40]'),
#  Text(0.19333317276427658, 0.82, 'X[10] <= 0.554\ngini = 0.057\nsamples = 2330\nvalue = [0, 0, 0, 2262, 6, 22, 40]'),
#  Text(0.1707170211228594, 0.78, 'X[13] <= 0.985\ngini = 0.457\nsamples = 66\nvalue = [0, 0, 0, 46, 0, 15, 5]'),
#  Text(0.16416580360798672, 0.74, 'X[5] <= 0.119\ngini = 0.364\nsamples = 55\nvalue = [0, 0, 0, 43, 0, 7, 5]'),
#  Text(0.1603121462462969, 0.7, 'X[6] <= 0.781\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 3, 1]'),
#  Text(0.15877068330162095, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.1618536091909728, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.16801946096967654, 0.7, 'X[0] <= 0.126\ngini = 0.277\nsamples = 51\nvalue = [0, 0, 0, 43, 0, 4, 4]'),
#  Text(0.16493653508032466, 0.66, 'X[8] <= 0.841\ngini = 0.201\nsamples = 45\nvalue = [0, 0, 0, 40, 0, 4, 1]'),
#  Text(0.16339507213564874, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.1664779980250006, 0.62, 'X[6] <= 0.842\ngini = 0.168\nsamples = 44\nvalue = [0, 0, 0, 40, 0, 3, 1]'),
#  Text(0.16493653508032466, 0.58, 'X[10] <= 0.547\ngini = 0.132\nsamples = 43\nvalue = [0, 0, 0, 40, 0, 2, 1]'),
#  Text(0.1618536091909728, 0.54, 'X[8] <= 0.908\ngini = 0.061\nsamples = 32\nvalue = [0, 0, 0, 31, 0, 0, 1]'),
#  Text(0.1603121462462969, 0.5, 'gini = 0.0\nsamples = 27\nvalue = [0, 0, 0, 27, 0, 0, 0]'),
#  Text(0.16339507213564874, 0.5, 'X[9] <= 0.608\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 0, 0, 1]'),
#  Text(0.1618536091909728, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.16493653508032466, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.16801946096967654, 0.54, 'X[10] <= 0.548\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 9, 0, 2, 0]'),
#  Text(0.1664779980250006, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.16956092391435246, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0, 0]'),
#  Text(0.16801946096967654, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.1711023868590284, 0.66, 'X[2] <= 0.176\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 3, 0, 0, 3]'),
#  Text(0.16956092391435246, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.17264384980370434, 0.62, 'X[11] <= 0.539\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 0, 1]'),
#  Text(0.1711023868590284, 0.58, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.17418531274838026, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.1772682386377321, 0.74, 'X[9] <= 0.636\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 3, 0, 8, 0]'),
#  Text(0.1757267756930562, 0.7, 'X[11] <= 0.551\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 0, 2, 0]'),
#  Text(0.17418531274838026, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.1772682386377321, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.17880970158240805, 0.7, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 6, 0]'),
#  Text(0.21594932440569378, 0.78, 'X[0] <= 0.118\ngini = 0.042\nsamples = 2264\nvalue = [0, 0, 0, 2216, 6, 7, 35]'),
#  Text(0.19306823382066043, 0.74, 'X[10] <= 0.588\ngini = 0.021\nsamples = 2055\nvalue = [0, 0, 0, 2033, 2, 7, 13]'),
#  Text(0.18381945615260484, 0.7, 'X[10] <= 0.587\ngini = 0.152\nsamples = 136\nvalue = [0, 0, 0, 125, 0, 5, 6]'),
#  Text(0.1822779932079289, 0.66, 'X[0] <= 0.091\ngini = 0.128\nsamples = 134\nvalue = [0, 0, 0, 125, 0, 5, 4]'),
#  Text(0.17880970158240805, 0.62, 'X[6] <= 0.731\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 0, 5, 0, 3, 0]'),
#  Text(0.1772682386377321, 0.58, 'X[3] <= 0.635\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 3, 0]'),
#  Text(0.1757267756930562, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.17880970158240805, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.180351164527084, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.18574628483344974, 0.62, 'X[6] <= 0.704\ngini = 0.092\nsamples = 126\nvalue = [0, 0, 0, 120, 0, 2, 4]'),
#  Text(0.18420482188877382, 0.58, 'gini = 0.0\nsamples = 74\nvalue = [0, 0, 0, 74, 0, 0, 0]'),
#  Text(0.18728774777812568, 0.58, 'X[6] <= 0.712\ngini = 0.21\nsamples = 52\nvalue = [0, 0, 0, 46, 0, 2, 4]'),
#  Text(0.1818926274717599, 0.54, 'X[8] <= 0.875\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 1, 2]'),
#  Text(0.180351164527084, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.18343409041643585, 0.5, 'X[10] <= 0.568\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1, 0]'),
#  Text(0.1818926274717599, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.18497555336111177, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.19268286808449145, 0.54, 'X[7] <= 0.932\ngini = 0.119\nsamples = 48\nvalue = [0, 0, 0, 45, 0, 1, 2]'),
#  Text(0.1911414051398155, 0.5, 'X[7] <= 0.93\ngini = 0.265\nsamples = 20\nvalue = [0, 0, 0, 17, 0, 1, 2]'),
#  Text(0.18805847925046365, 0.46, 'X[6] <= 0.819\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 0, 17, 0, 0, 1]'),
#  Text(0.1865170163057877, 0.42, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0, 0]'),
#  Text(0.18959994219513956, 0.42, 'X[7] <= 0.912\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]'),
#  Text(0.18805847925046365, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.1911414051398155, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.19422433102916736, 0.46, 'X[8] <= 0.899\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 1, 1]'),
#  Text(0.19268286808449145, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.1957657939738433, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.19422433102916736, 0.5, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0, 0, 0]'),
#  Text(0.18536091909728075, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.202317011488716, 0.7, 'X[1] <= 0.158\ngini = 0.011\nsamples = 1919\nvalue = [0, 0, 0, 1908, 2, 2, 7]'),
#  Text(0.1980779883908572, 0.66, 'X[13] <= 0.7\ngini = 0.01\nsamples = 1917\nvalue = [0, 0, 0, 1907, 1, 2, 7]'),
#  Text(0.19422433102916736, 0.62, 'X[8] <= 0.784\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.19268286808449145, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.1957657939738433, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.20193164575254702, 0.62, 'X[1] <= 0.129\ngini = 0.009\nsamples = 1915\nvalue = [0, 0, 0, 1906, 1, 2, 6]'),
#  Text(0.19884871986319516, 0.58, 'X[2] <= 0.144\ngini = 0.002\nsamples = 1686\nvalue = [0, 0, 0, 1684, 0, 2, 0]'),
#  Text(0.19730725691851922, 0.54, 'gini = 0.0\nsamples = 1566\nvalue = [0, 0, 0, 1566, 0, 0, 0]'),
#  Text(0.2003901828078711, 0.54, 'X[2] <= 0.144\ngini = 0.033\nsamples = 120\nvalue = [0, 0, 0, 118, 0, 2, 0]'),
#  Text(0.19884871986319516, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.20193164575254702, 0.5, 'X[8] <= 0.819\ngini = 0.017\nsamples = 119\nvalue = [0, 0, 0, 118, 0, 1, 0]'),
#  Text(0.2003901828078711, 0.46, 'X[7] <= 0.899\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 0, 1, 0]'),
#  Text(0.19884871986319516, 0.42, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.20193164575254702, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.20347310869722296, 0.46, 'gini = 0.0\nsamples = 113\nvalue = [0, 0, 0, 113, 0, 0, 0]'),
#  Text(0.2050145716418989, 0.58, 'X[1] <= 0.129\ngini = 0.059\nsamples = 229\nvalue = [0, 0, 0, 222, 1, 0, 6]'),
#  Text(0.20347310869722296, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.20655603458657482, 0.54, 'X[6] <= 0.595\ngini = 0.051\nsamples = 228\nvalue = [0, 0, 0, 222, 1, 0, 5]'),
#  Text(0.2050145716418989, 0.5, 'gini = 0.0\nsamples = 112\nvalue = [0, 0, 0, 112, 0, 0, 0]'),
#  Text(0.20809749753125076, 0.5, 'X[6] <= 0.598\ngini = 0.099\nsamples = 116\nvalue = [0, 0, 0, 110, 1, 0, 5]'),
#  Text(0.20655603458657482, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.20963896047592667, 0.46, 'X[13] <= 0.942\ngini = 0.084\nsamples = 115\nvalue = [0, 0, 0, 110, 1, 0, 4]'),
#  Text(0.20655603458657482, 0.42, 'X[13] <= 0.941\ngini = 0.185\nsamples = 29\nvalue = [0, 0, 0, 26, 0, 0, 3]'),
#  Text(0.2050145716418989, 0.38, 'X[7] <= 0.899\ngini = 0.071\nsamples = 27\nvalue = [0, 0, 0, 26, 0, 0, 1]'),
#  Text(0.20347310869722296, 0.34, 'X[8] <= 0.807\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 0, 0, 1]'),
#  Text(0.20193164575254702, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.2050145716418989, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.20655603458657482, 0.34, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 0, 21, 0, 0, 0]'),
#  Text(0.20809749753125076, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.21272188636527856, 0.42, 'X[8] <= 0.801\ngini = 0.046\nsamples = 86\nvalue = [0, 0, 0, 84, 1, 0, 1]'),
#  Text(0.21118042342060261, 0.38, 'X[8] <= 0.794\ngini = 0.215\nsamples = 17\nvalue = [0, 0, 0, 15, 1, 0, 1]'),
#  Text(0.20963896047592667, 0.34, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0, 0]'),
#  Text(0.21272188636527856, 0.34, 'X[0] <= 0.114\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 0, 1]'),
#  Text(0.21118042342060261, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.21426334930995447, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.21426334930995447, 0.38, 'gini = 0.0\nsamples = 69\nvalue = [0, 0, 0, 69, 0, 0, 0]'),
#  Text(0.20655603458657482, 0.66, 'X[7] <= 0.952\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0]'),
#  Text(0.2050145716418989, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.20809749753125076, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.23883041499072713, 0.74, 'X[7] <= 0.902\ngini = 0.222\nsamples = 209\nvalue = [0, 0, 0, 183, 4, 0, 22]'),
#  Text(0.23006334449288277, 0.7, 'X[7] <= 0.9\ngini = 0.452\nsamples = 48\nvalue = [0, 0, 0, 33, 2, 0, 13]'),
#  Text(0.22428285845034804, 0.66, 'X[3] <= 0.795\ngini = 0.385\nsamples = 44\nvalue = [0, 0, 0, 33, 1, 0, 10]'),
#  Text(0.21734627519930635, 0.62, 'X[1] <= 0.127\ngini = 0.469\nsamples = 24\nvalue = [0, 0, 0, 15, 0, 0, 9]'),
#  Text(0.2158048122546304, 0.58, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0, 0]'),
#  Text(0.21888773814398227, 0.58, 'X[8] <= 0.81\ngini = 0.498\nsamples = 17\nvalue = [0, 0, 0, 8, 0, 0, 9]'),
#  Text(0.2158048122546304, 0.54, 'X[0] <= 0.125\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 2, 0, 0, 8]'),
#  Text(0.21426334930995447, 0.5, 'X[8] <= 0.746\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 1, 0, 0, 8]'),
#  Text(0.21272188636527856, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.2158048122546304, 0.46, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 0, 0, 8]'),
#  Text(0.21734627519930635, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.22197066403333413, 0.54, 'X[12] <= 0.491\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 0, 1]'),
#  Text(0.2204292010886582, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0, 0]'),
#  Text(0.22351212697801007, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.23121944170138972, 0.62, 'X[1] <= 0.166\ngini = 0.185\nsamples = 20\nvalue = [0, 0, 0, 18, 1, 0, 1]'),
#  Text(0.22967797875671378, 0.58, 'X[13] <= 0.789\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 18, 0, 0, 1]'),
#  Text(0.22813651581203787, 0.54, 'X[4] <= 0.045\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.22659505286736192, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.22967797875671378, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.23121944170138972, 0.54, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 17, 0, 0, 0]'),
#  Text(0.23276090464606566, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.23584383053541752, 0.66, 'X[8] <= 0.783\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 0, 3]'),
#  Text(0.23430236759074158, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.23738529348009346, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.2475974854885715, 0.7, 'X[10] <= 0.682\ngini = 0.129\nsamples = 161\nvalue = [0, 0, 0, 150, 2, 0, 9]'),
#  Text(0.24605602254389555, 0.66, 'X[0] <= 0.118\ngini = 0.118\nsamples = 160\nvalue = [0, 0, 0, 150, 1, 0, 9]'),
#  Text(0.24451455959921964, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2475974854885715, 0.62, 'X[6] <= 0.816\ngini = 0.107\nsamples = 159\nvalue = [0, 0, 0, 150, 1, 0, 8]'),
#  Text(0.23931212216093836, 0.58, 'X[10] <= 0.564\ngini = 0.088\nsamples = 152\nvalue = [0, 0, 0, 145, 1, 0, 6]'),
#  Text(0.23430236759074158, 0.54, 'X[2] <= 0.17\ngini = 0.32\nsamples = 15\nvalue = [0, 0, 0, 12, 0, 0, 3]'),
#  Text(0.23276090464606566, 0.5, 'X[9] <= 0.544\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 3]'),
#  Text(0.23121944170138972, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.23430236759074158, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.23584383053541752, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0, 0]'),
#  Text(0.24432187673113515, 0.54, 'X[13] <= 0.93\ngini = 0.057\nsamples = 137\nvalue = [0, 0, 0, 133, 1, 0, 3]'),
#  Text(0.23892675642476938, 0.5, 'X[13] <= 0.929\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 0, 18, 0, 0, 2]'),
#  Text(0.23738529348009346, 0.46, 'X[5] <= 0.131\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 18, 0, 0, 1]'),
#  Text(0.23584383053541752, 0.42, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0, 0]'),
#  Text(0.23892675642476938, 0.42, 'X[0] <= 0.124\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]'),
#  Text(0.23738529348009346, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.24046821936944532, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.24046821936944532, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.24971699703750092, 0.5, 'X[1] <= 0.155\ngini = 0.034\nsamples = 117\nvalue = [0, 0, 0, 115, 1, 0, 1]'),
#  Text(0.24663407114814903, 0.46, 'X[6] <= 0.491\ngini = 0.019\nsamples = 102\nvalue = [0, 0, 0, 101, 1, 0, 0]'),
#  Text(0.24509260820347312, 0.42, 'X[6] <= 0.491\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 0, 15, 1, 0, 0]'),
#  Text(0.24355114525879717, 0.38, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0, 0]'),
#  Text(0.24663407114814903, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.24817553409282497, 0.42, 'gini = 0.0\nsamples = 86\nvalue = [0, 0, 0, 86, 0, 0, 0]'),
#  Text(0.25279992292685277, 0.46, 'X[1] <= 0.155\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 0, 14, 0, 0, 1]'),
#  Text(0.25125845998217683, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2543413858715287, 0.42, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0, 0]'),
#  Text(0.25588284881620466, 0.58, 'X[6] <= 0.837\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 0, 0, 2]'),
#  Text(0.2543413858715287, 0.54, 'X[1] <= 0.146\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.25279992292685277, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.25588284881620466, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.25742431176088054, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.24913894843324744, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.2475974854885715, 0.82, 'X[10] <= 0.557\ngini = 0.375\nsamples = 52\nvalue = [0, 0, 0, 13, 0, 39, 0]'),
#  Text(0.24451455959921964, 0.78, 'X[5] <= 0.116\ngini = 0.051\nsamples = 38\nvalue = [0, 0, 0, 1, 0, 37, 0]'),
#  Text(0.2429730966545437, 0.74, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 0, 0, 0, 37, 0]'),
#  Text(0.24605602254389555, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.25068041137792335, 0.78, 'X[13] <= 0.982\ngini = 0.245\nsamples = 14\nvalue = [0, 0, 0, 12, 0, 2, 0]'),
#  Text(0.24913894843324744, 0.74, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0, 0]'),
#  Text(0.2522218743225993, 0.74, 'X[10] <= 0.611\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 2, 0]'),
#  Text(0.25068041137792335, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(0.25376333726727524, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.3724439413280667, 0.86, 'X[0] <= 0.147\ngini = 0.472\nsamples = 601\nvalue = [0, 0, 0, 381, 3, 4, 213]'),
#  Text(0.33042703340639223, 0.82, 'X[6] <= 0.718\ngini = 0.432\nsamples = 463\nvalue = [0, 0, 0, 321, 3, 2, 137]'),
#  Text(0.2939377152628917, 0.78, 'X[8] <= 0.823\ngini = 0.376\nsamples = 309\nvalue = [0, 0, 0, 233, 1, 2, 73]'),
#  Text(0.275247477058696, 0.74, 'X[9] <= 0.423\ngini = 0.474\nsamples = 155\nvalue = [0, 0, 0, 98, 1, 1, 55]'),
#  Text(0.2682145523736121, 0.7, 'X[8] <= 0.779\ngini = 0.245\nsamples = 35\nvalue = [0, 0, 0, 30, 0, 0, 5]'),
#  Text(0.26667308942893614, 0.66, 'X[8] <= 0.776\ngini = 0.43\nsamples = 16\nvalue = [0, 0, 0, 11, 0, 0, 5]'),
#  Text(0.2651316264842602, 0.62, 'X[7] <= 0.925\ngini = 0.337\nsamples = 14\nvalue = [0, 0, 0, 11, 0, 0, 3]'),
#  Text(0.26204870059490837, 0.58, 'X[6] <= 0.526\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 0, 0, 1]'),
#  Text(0.2605072376502324, 0.54, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0, 0]'),
#  Text(0.2635901635395843, 0.54, 'X[6] <= 0.576\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]'),
#  Text(0.26204870059490837, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2651316264842602, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.2682145523736121, 0.58, 'X[10] <= 0.62\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.26667308942893614, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.269756015318288, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.2682145523736121, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.269756015318288, 0.66, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0, 0]'),
#  Text(0.28228040174377994, 0.7, 'X[13] <= 0.94\ngini = 0.505\nsamples = 120\nvalue = [0, 0, 0, 68, 1, 1, 50]'),
#  Text(0.2774633300416677, 0.66, 'X[13] <= 0.938\ngini = 0.514\nsamples = 68\nvalue = [0, 0, 0, 33, 1, 0, 34]'),
#  Text(0.27592186709699174, 0.62, 'X[0] <= 0.145\ngini = 0.512\nsamples = 62\nvalue = [0, 0, 0, 33, 1, 0, 28]'),
#  Text(0.2743804041523158, 0.58, 'X[4] <= 0.062\ngini = 0.517\nsamples = 57\nvalue = [0, 0, 0, 28, 1, 0, 28]'),
#  Text(0.27283894120763985, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.27592186709699174, 0.54, 'X[7] <= 0.88\ngini = 0.515\nsamples = 53\nvalue = [0, 0, 0, 24, 1, 0, 28]'),
#  Text(0.27149016113104846, 0.5, 'X[1] <= 0.153\ngini = 0.426\nsamples = 18\nvalue = [0, 0, 0, 4, 1, 0, 13]'),
#  Text(0.2699486981863725, 0.46, 'X[1] <= 0.15\ngini = 0.593\nsamples = 9\nvalue = [0, 0, 0, 4, 1, 0, 4]'),
#  Text(0.2684072352416966, 0.42, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 0, 4]'),
#  Text(0.27149016113104846, 0.42, 'X[5] <= 0.126\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0, 0]'),
#  Text(0.2699486981863725, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.27303162407572434, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.27303162407572434, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 0, 0, 0, 9]'),
#  Text(0.28035357306293507, 0.5, 'X[4] <= 0.065\ngini = 0.49\nsamples = 35\nvalue = [0, 0, 0, 20, 0, 0, 15]'),
#  Text(0.27611454996507623, 0.46, 'X[0] <= 0.127\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 0, 0, 5]'),
#  Text(0.2745730870204003, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.27765601290975217, 0.42, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 5]'),
#  Text(0.28459259616079385, 0.46, 'X[6] <= 0.529\ngini = 0.452\nsamples = 29\nvalue = [0, 0, 0, 19, 0, 0, 10]'),
#  Text(0.280738938799104, 0.42, 'X[7] <= 0.926\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 11, 0, 0, 1]'),
#  Text(0.2791974758544281, 0.38, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0, 0]'),
#  Text(0.28228040174377994, 0.38, 'X[2] <= 0.162\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.280738938799104, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.2838218646884559, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2884462535224837, 0.42, 'X[13] <= 0.893\ngini = 0.498\nsamples = 17\nvalue = [0, 0, 0, 8, 0, 0, 9]'),
#  Text(0.28690479057780777, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.2899877164671596, 0.38, 'X[13] <= 0.92\ngini = 0.49\nsamples = 14\nvalue = [0, 0, 0, 8, 0, 0, 6]'),
#  Text(0.28690479057780777, 0.34, 'X[0] <= 0.141\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 0, 1]'),
#  Text(0.2853633276331318, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0, 0]'),
#  Text(0.2884462535224837, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2930706423565115, 0.34, 'X[8] <= 0.794\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 2, 0, 0, 5]'),
#  Text(0.29152917941183554, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.2946121053011874, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 5]'),
#  Text(0.2774633300416677, 0.58, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.2790047929863436, 0.62, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(0.28709747344589226, 0.66, 'X[12] <= 0.418\ngini = 0.452\nsamples = 52\nvalue = [0, 0, 0, 35, 0, 1, 16]'),
#  Text(0.28208771887569545, 0.62, 'X[6] <= 0.449\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 0, 17, 0, 0, 1]'),
#  Text(0.2805462559310195, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.2836291818203714, 0.58, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 17, 0, 0, 0]'),
#  Text(0.292107228016089, 0.62, 'X[7] <= 0.894\ngini = 0.524\nsamples = 34\nvalue = [0, 0, 0, 18, 0, 1, 15]'),
#  Text(0.2867121077097233, 0.58, 'X[12] <= 0.499\ngini = 0.403\nsamples = 12\nvalue = [0, 0, 0, 9, 0, 1, 2]'),
#  Text(0.28517064476504733, 0.54, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0, 0]'),
#  Text(0.2882535706543992, 0.54, 'X[9] <= 0.565\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 2, 0, 1, 2]'),
#  Text(0.2867121077097233, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.2897950335990751, 0.5, 'X[1] <= 0.118\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1, 0]'),
#  Text(0.2882535706543992, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.29133649654375104, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.29750234832245476, 0.58, 'X[7] <= 0.906\ngini = 0.483\nsamples = 22\nvalue = [0, 0, 0, 9, 0, 0, 13]'),
#  Text(0.29596088537777887, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(0.2990438112671307, 0.54, 'X[2] <= 0.163\ngini = 0.492\nsamples = 16\nvalue = [0, 0, 0, 9, 0, 0, 7]'),
#  Text(0.29596088537777887, 0.5, 'X[6] <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 0, 3, 0, 0, 6]'),
#  Text(0.29441942243310293, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.29750234832245476, 0.46, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(0.3021267371564826, 0.5, 'X[4] <= 0.075\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 0, 1]'),
#  Text(0.30058527421180664, 0.46, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0, 0]'),
#  Text(0.3036682001011585, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.3126279534670874, 0.74, 'X[1] <= 0.133\ngini = 0.218\nsamples = 154\nvalue = [0, 0, 0, 135, 0, 1, 18]'),
#  Text(0.3095450275777355, 0.7, 'X[0] <= 0.13\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.30800356463305956, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.31108649052241144, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.3157108793564392, 0.7, 'X[7] <= 0.976\ngini = 0.201\nsamples = 151\nvalue = [0, 0, 0, 134, 0, 1, 16]'),
#  Text(0.31416941641176327, 0.66, 'X[9] <= 0.512\ngini = 0.192\nsamples = 150\nvalue = [0, 0, 0, 134, 0, 1, 15]'),
#  Text(0.30675112599051035, 0.62, 'X[6] <= 0.46\ngini = 0.056\nsamples = 70\nvalue = [0, 0, 0, 68, 0, 0, 2]'),
#  Text(0.3036682001011585, 0.58, 'X[3] <= 0.774\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 0, 0, 1]'),
#  Text(0.3021267371564826, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.3052096630458344, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.30983405187986224, 0.58, 'X[10] <= 0.55\ngini = 0.03\nsamples = 66\nvalue = [0, 0, 0, 65, 0, 0, 1]'),
#  Text(0.3082925889351863, 0.54, 'X[10] <= 0.549\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 0, 0, 1]'),
#  Text(0.30675112599051035, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0, 0]'),
#  Text(0.30983405187986224, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.3113755148245382, 0.54, 'gini = 0.0\nsamples = 58\nvalue = [0, 0, 0, 58, 0, 0, 0]'),
#  Text(0.3215877068330162, 0.62, 'X[9] <= 0.515\ngini = 0.293\nsamples = 80\nvalue = [0, 0, 0, 66, 0, 1, 13]'),
# ...
#  Text(0.5819022616151641, 0.38, 'X[4] <= 0.09\ngini = 0.298\nsamples = 33\nvalue = [0, 0, 0, 6, 0, 0, 27]'),
#  Text(0.5803607986704882, 0.34, 'X[8] <= 0.748\ngini = 0.264\nsamples = 32\nvalue = [0, 0, 0, 5, 0, 0, 27]'),
#  Text(0.5788193357258122, 0.3, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 0, 0, 0, 17]'),
#  Text(0.5819022616151641, 0.3, 'X[10] <= 0.587\ngini = 0.444\nsamples = 15\nvalue = [0, 0, 0, 5, 0, 0, 10]'),
#  Text(0.5803607986704882, 0.26, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(0.5834437245598401, 0.26, 'X[0] <= 0.157\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 5, 0, 0, 4]'),
#  Text(0.5819022616151641, 0.22, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.584985187504516, 0.22, 'X[0] <= 0.173\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 0, 0, 2]'),
#  Text(0.5834437245598401, 0.18, 'X[13] <= 0.877\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 0, 0, 1]'),
#  Text(0.5819022616151641, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.584985187504516, 0.14, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.5865266504491919, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.5834437245598401, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.5819022616151641, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]'),
#  Text(0.5834437245598401, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(0.5930778679640647, 0.54, 'X[11] <= 0.422\ngini = 0.135\nsamples = 137\nvalue = [0, 0, 0, 10, 0, 0, 127]'),
#  Text(0.5888388448662059, 0.5, 'X[4] <= 0.079\ngini = 0.112\nsamples = 134\nvalue = [0, 0, 0, 8, 0, 0, 126]'),
#  Text(0.584985187504516, 0.46, 'X[4] <= 0.079\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.5834437245598401, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.5865266504491919, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.5926925022278957, 0.46, 'X[13] <= 0.77\ngini = 0.1\nsamples = 132\nvalue = [0, 0, 0, 7, 0, 0, 125]'),
#  Text(0.5896095763385438, 0.42, 'X[10] <= 0.548\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.5880681133938679, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.5911510392832198, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.5957754281172475, 0.42, 'X[13] <= 0.903\ngini = 0.088\nsamples = 130\nvalue = [0, 0, 0, 6, 0, 0, 124]'),
#  Text(0.5942339651725715, 0.38, 'gini = 0.0\nsamples = 60\nvalue = [0, 0, 0, 0, 0, 0, 60]'),
#  Text(0.5973168910619234, 0.38, 'X[13] <= 0.903\ngini = 0.157\nsamples = 70\nvalue = [0, 0, 0, 6, 0, 0, 64]'),
#  Text(0.5957754281172475, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.5988583540065994, 0.34, 'X[4] <= 0.087\ngini = 0.134\nsamples = 69\nvalue = [0, 0, 0, 5, 0, 0, 64]'),
#  Text(0.5973168910619234, 0.3, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 0, 0, 0, 0, 35]'),
#  Text(0.6003998169512753, 0.3, 'X[4] <= 0.088\ngini = 0.251\nsamples = 34\nvalue = [0, 0, 0, 5, 0, 0, 29]'),
#  Text(0.5988583540065994, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.6019412798959513, 0.26, 'X[6] <= 0.509\ngini = 0.17\nsamples = 32\nvalue = [0, 0, 0, 3, 0, 0, 29]'),
#  Text(0.5988583540065994, 0.22, 'X[6] <= 0.47\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 2, 0, 0, 5]'),
#  Text(0.5973168910619234, 0.18, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 5]'),
#  Text(0.6003998169512753, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.6050242057853031, 0.22, 'X[8] <= 0.832\ngini = 0.077\nsamples = 25\nvalue = [0, 0, 0, 1, 0, 0, 24]'),
#  Text(0.6034827428406272, 0.18, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 0, 0, 0, 22]'),
#  Text(0.6065656687299791, 0.18, 'X[2] <= 0.188\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 0, 0, 2]'),
#  Text(0.6050242057853031, 0.14, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.608107131674655, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.5973168910619234, 0.5, 'X[11] <= 0.423\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]'),
#  Text(0.5957754281172475, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.5988583540065994, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6034827428406272, 0.58, 'X[10] <= 0.616\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 0, 1, 5, 0, 1]'),
#  Text(0.6019412798959513, 0.54, 'X[4] <= 0.088\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.6003998169512753, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.6034827428406272, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6050242057853031, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0, 0]'),
#  Text(0.6252559069341748, 0.62, 'X[8] <= 0.836\ngini = 0.481\nsamples = 105\nvalue = [1, 0, 0, 37, 0, 1, 66]'),
#  Text(0.6192827380235555, 0.58, 'X[2] <= 0.18\ngini = 0.444\nsamples = 93\nvalue = [1, 0, 0, 29, 0, 0, 63]'),
#  Text(0.6119607890363448, 0.54, 'X[8] <= 0.792\ngini = 0.496\nsamples = 55\nvalue = [0, 0, 0, 25, 0, 0, 30]'),
#  Text(0.6065656687299791, 0.5, 'X[9] <= 0.325\ngini = 0.426\nsamples = 39\nvalue = [0, 0, 0, 12, 0, 0, 27]'),
#  Text(0.6050242057853031, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]'),
#  Text(0.608107131674655, 0.46, 'X[11] <= 0.33\ngini = 0.394\nsamples = 37\nvalue = [0, 0, 0, 10, 0, 0, 27]'),
#  Text(0.6050242057853031, 0.42, 'X[7] <= 0.944\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 0, 1, 0, 0, 16]'),
#  Text(0.6034827428406272, 0.38, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 0, 0, 16]'),
#  Text(0.6065656687299791, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.6111900575640068, 0.42, 'X[6] <= 0.732\ngini = 0.495\nsamples = 20\nvalue = [0, 0, 0, 9, 0, 0, 11]'),
#  Text(0.609648594619331, 0.38, 'X[3] <= 0.814\ngini = 0.426\nsamples = 13\nvalue = [0, 0, 0, 9, 0, 0, 4]'),
#  Text(0.608107131674655, 0.34, 'X[11] <= 0.379\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 0, 0, 4]'),
#  Text(0.6065656687299791, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.609648594619331, 0.3, 'X[5] <= 0.15\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 0, 0, 1]'),
#  Text(0.608107131674655, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6111900575640068, 0.26, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0, 0]'),
#  Text(0.6111900575640068, 0.34, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0, 0]'),
#  Text(0.6127315205086827, 0.38, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 0, 7]'),
#  Text(0.6173559093427106, 0.5, 'X[4] <= 0.086\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 0, 13, 0, 0, 3]'),
#  Text(0.6158144463980346, 0.46, 'X[13] <= 0.951\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 0, 3]'),
#  Text(0.6142729834533587, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.6173559093427106, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.6188973722873865, 0.46, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0, 0]'),
#  Text(0.6266046870107661, 0.54, 'X[3] <= 0.803\ngini = 0.234\nsamples = 38\nvalue = [1, 0, 0, 4, 0, 0, 33]'),
#  Text(0.6250632240660903, 0.5, 'X[6] <= 0.838\ngini = 0.197\nsamples = 37\nvalue = [1, 0, 0, 3, 0, 0, 33]'),
#  Text(0.6235217611214143, 0.46, 'X[0] <= 0.161\ngini = 0.156\nsamples = 36\nvalue = [1, 0, 0, 2, 0, 0, 33]'),
#  Text(0.6204388352320624, 0.42, 'X[2] <= 0.186\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6188973722873865, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6219802981767384, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6266046870107661, 0.42, 'X[1] <= 0.181\ngini = 0.114\nsamples = 33\nvalue = [0, 0, 0, 2, 0, 0, 31]'),
#  Text(0.6250632240660903, 0.38, 'X[1] <= 0.181\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 0, 2, 0, 0, 14]'),
#  Text(0.6235217611214143, 0.34, 'X[9] <= 0.479\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 0, 1, 0, 0, 14]'),
#  Text(0.6219802981767384, 0.3, 'X[0] <= 0.163\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]'),
#  Text(0.6204388352320624, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6235217611214143, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.6250632240660903, 0.3, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 0, 0, 0, 13]'),
#  Text(0.6266046870107661, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.628146149955442, 0.38, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 0, 0, 0, 0, 17]'),
#  Text(0.6266046870107661, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.628146149955442, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.6312290758447939, 0.58, 'X[0] <= 0.157\ngini = 0.486\nsamples = 12\nvalue = [0, 0, 0, 8, 0, 1, 3]'),
#  Text(0.629687612900118, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6327705387894699, 0.54, 'X[9] <= 0.458\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 0, 8, 0, 1, 1]'),
#  Text(0.6312290758447939, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.6343120017341458, 0.5, 'X[13] <= 0.977\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 0, 0, 1]'),
#  Text(0.6327705387894699, 0.46, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0, 0]'),
#  Text(0.6358534646788218, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6530473999855488, 0.66, 'X[12] <= 0.241\ngini = 0.085\nsamples = 1422\nvalue = [12, 0, 7, 0, 25, 18, 1360]'),
#  Text(0.6404778535128496, 0.62, 'X[13] <= 0.907\ngini = 0.539\nsamples = 16\nvalue = [0, 0, 1, 0, 9, 0, 6]'),
#  Text(0.6373949276234977, 0.58, 'X[4] <= 0.132\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 0, 6, 0, 1]'),
#  Text(0.6358534646788218, 0.54, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0, 0]'),
#  Text(0.6389363905681736, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6435607794022014, 0.58, 'X[4] <= 0.128\ngini = 0.568\nsamples = 9\nvalue = [0, 0, 1, 0, 3, 0, 5]'),
#  Text(0.6420193164575255, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 0, 5]'),
#  Text(0.6451022423468773, 0.54, 'X[2] <= 0.209\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 3, 0, 0]'),
#  Text(0.6435607794022014, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0, 0]'),
#  Text(0.6466437052915532, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.665616946458248, 0.62, 'X[13] <= 0.66\ngini = 0.072\nsamples = 1406\nvalue = [12, 0, 6, 0, 16, 18, 1354]'),
#  Text(0.652809557070257, 0.58, 'X[9] <= 0.421\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 0, 0, 5, 0, 3]'),
#  Text(0.6512680941255811, 0.54, 'X[10] <= 0.54\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 0, 5, 0, 1]'),
#  Text(0.6497266311809051, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0, 0]'),
#  Text(0.652809557070257, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.654351020014933, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6784243358462391, 0.58, 'X[10] <= 0.428\ngini = 0.066\nsamples = 1398\nvalue = [12, 0, 6, 0, 11, 18, 1351]'),
#  Text(0.6589754088489607, 0.54, 'X[13] <= 0.957\ngini = 0.576\nsamples = 19\nvalue = [4, 0, 0, 0, 0, 4, 11]'),
#  Text(0.6558924829596089, 0.5, 'X[8] <= 0.83\ngini = 0.272\nsamples = 13\nvalue = [1, 0, 0, 0, 0, 1, 11]'),
#  Text(0.654351020014933, 0.46, 'X[5] <= 0.236\ngini = 0.153\nsamples = 12\nvalue = [1, 0, 0, 0, 0, 0, 11]'),
#  Text(0.652809557070257, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6558924829596089, 0.42, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 0, 0, 11]'),
#  Text(0.6574339459042848, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.6620583347383125, 0.5, 'X[1] <= 0.237\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 0, 0, 3, 0]'),
#  Text(0.6605168717936366, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6635997976829885, 0.46, 'X[13] <= 0.961\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 0, 0, 3, 0]'),
#  Text(0.6620583347383125, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6651412606276644, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]'),
#  Text(0.6978732628435175, 0.54, 'X[13] <= 0.983\ngini = 0.056\nsamples = 1379\nvalue = [8, 0, 6, 0, 11, 14, 1340]'),
#  Text(0.6869625954382331, 0.5, 'X[10] <= 0.597\ngini = 0.05\nsamples = 1369\nvalue = [8, 0, 5, 0, 11, 11, 1334]'),
#  Text(0.6854211324935572, 0.46, 'X[13] <= 0.96\ngini = 0.049\nsamples = 1368\nvalue = [8, 0, 5, 0, 10, 11, 1334]'),
#  Text(0.6682241865170163, 0.42, 'X[10] <= 0.583\ngini = 0.033\nsamples = 1194\nvalue = [4, 0, 4, 0, 9, 3, 1174]'),
#  Text(0.6604205303595944, 0.38, 'X[7] <= 0.863\ngini = 0.032\nsamples = 1191\nvalue = [4, 0, 4, 0, 8, 3, 1172]'),
#  Text(0.6494376068787784, 0.34, 'X[13] <= 0.932\ngini = 0.144\nsamples = 92\nvalue = [3, 0, 1, 0, 3, 0, 85]'),
#  Text(0.6455839495170885, 0.3, 'X[0] <= 0.251\ngini = 0.088\nsamples = 88\nvalue = [1, 0, 1, 0, 2, 0, 84]'),
#  Text(0.6440424865724126, 0.26, 'X[2] <= 0.176\ngini = 0.067\nsamples = 87\nvalue = [1, 0, 0, 0, 2, 0, 84]'),
#  Text(0.6409595606830608, 0.22, 'X[2] <= 0.171\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 0, 2]'),
#  Text(0.6394180977383849, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6425010236277366, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.6471254124617645, 0.22, 'X[7] <= 0.856\ngini = 0.047\nsamples = 84\nvalue = [1, 0, 0, 0, 1, 0, 82]'),
#  Text(0.6455839495170885, 0.18, 'gini = 0.0\nsamples = 66\nvalue = [0, 0, 0, 0, 0, 0, 66]'),
#  Text(0.6486668754064404, 0.18, 'X[7] <= 0.856\ngini = 0.204\nsamples = 18\nvalue = [1, 0, 0, 0, 1, 0, 16]'),
#  Text(0.6471254124617645, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.6502083383511164, 0.14, 'X[3] <= 0.769\ngini = 0.111\nsamples = 17\nvalue = [1, 0, 0, 0, 0, 0, 16]'),
#  Text(0.6486668754064404, 0.1, 'X[2] <= 0.237\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6471254124617645, 0.06, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(0.6502083383511164, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6517498012957923, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 0, 0, 0, 14]'),
#  Text(0.6471254124617645, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(0.6532912642404682, 0.3, 'X[5] <= 0.198\ngini = 0.625\nsamples = 4\nvalue = [2, 0, 0, 0, 1, 0, 1]'),
#  Text(0.6517498012957923, 0.26, 'X[0] <= 0.186\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 0, 1]'),
#  Text(0.6502083383511164, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.6532912642404682, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.6548327271851442, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6714034538404104, 0.34, 'X[12] <= 0.26\ngini = 0.022\nsamples = 1099\nvalue = [1, 0, 3, 0, 5, 3, 1087]'),
#  Text(0.6594571160191719, 0.3, 'X[3] <= 0.88\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 0, 0, 2, 0, 10]'),
#  Text(0.6579156530744961, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.6609985789638478, 0.26, 'X[10] <= 0.542\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 0, 1, 0, 10]'),
#  Text(0.6594571160191719, 0.22, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 0, 0, 7]'),
#  Text(0.6625400419085238, 0.22, 'X[5] <= 0.204\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 0, 3]'),
#  Text(0.6609985789638478, 0.18, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(0.6640815048531997, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.6833497916616489, 0.3, 'X[0] <= 0.241\ngini = 0.018\nsamples = 1087\nvalue = [1, 0, 3, 0, 3, 3, 1077]'),
#  ...]

# %%
clean= DecisionTreeClassifier(random_state=0)
path = clean.cost_complexity_pruning_path(x_train, y_train)
ccp_alphas,impurities = path.ccp_alphas,path.impurities

# %%
#最大有效 alpha 值被移除，因為它是只有一個節點的平凡樹。
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker='o', drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
# Out:
# Text(0.5, 1.0, 'Total Impurity vs effective alpha for training set')

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)
print(
    "Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
        clfs[-1].tree_.node_count, ccp_alphas[-1]
    )
)
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.1442872066341887

# %%
clfs = clfs[:-1]
ccp_alphas = ccp_alphas[:-1]

node_counts = [clf.tree_.node_count for clf in clfs]
depth = [clf.tree_.max_depth for clf in clfs]
fig, ax = plt.subplots(2, 1)
ax[0].plot(ccp_alphas, node_counts, marker="o", drawstyle="steps-post")
ax[0].set_xlabel("alpha")
ax[0].set_ylabel("number of nodes")
ax[0].set_title("Number of nodes vs alpha")
ax[1].plot(ccp_alphas, depth, marker="o", drawstyle="steps-post")
ax[1].set_xlabel("alpha")
ax[1].set_ylabel("depth of tree")
ax[1].set_title("Depth vs alpha")
fig.tight_layout()

#節點數量和樹深度隨著 alpha 的增加而減少。

# %%
train_scores = [clf.score(x_train, y_train) for clf in clfs]
test_scores = [clf.score(x_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
x= df3

# %%
y
# Out:
# array([5, 5, 5, ..., 3, 3, 3])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
list = []
k = 0
while k <= 10:
    k = k+1
    clf1 = tree.DecisionTreeClassifier(criterion='gini',ccp_alpha=0.026,max_depth=k)
    clf1.fit(x_train, y_train)
    list.append(clf1.score(x_train,y_train))

print(list)
print(max(list))
print(list.index(max(list))+1)
# Out:
# [0.40659441587068335, 0.6537472446730346, 0.7636847905951506, 0.8012490815576782, 0.8595701689933872, 0.8595701689933872, 0.8595701689933872, 0.8595701689933872, 0.8595701689933872, 0.8595701689933872, 0.8595701689933872]
# 0.8595701689933872
# 5

# %%
clf4 = tree.DecisionTreeClassifier(criterion='gini',ccp_alpha=0.026,max_depth=5)
clf4.fit(x_train, y_train)
tree.plot_tree(clf4)
# Out:
# [Text(0.36363636363636365, 0.9166666666666666, 'X[1] <= 0.175\ngini = 0.827\nsamples = 10888\nvalue = [1060, 415, 1317, 2835, 1531, 1624, 2106]'),
#  Text(0.18181818181818182, 0.75, 'X[10] <= 0.529\ngini = 0.54\nsamples = 4587\nvalue = [2, 0, 1, 2702, 9, 1492, 381]'),
#  Text(0.09090909090909091, 0.5833333333333334, 'gini = 0.24\nsamples = 1636\nvalue = [2, 0, 1, 87, 0, 1418, 128]'),
#  Text(0.2727272727272727, 0.5833333333333334, 'gini = 0.207\nsamples = 2951\nvalue = [0, 0, 0, 2615, 9, 74, 253]'),
#  Text(0.5454545454545454, 0.75, 'X[9] <= 0.253\ngini = 0.79\nsamples = 6301\nvalue = [1058, 415, 1316, 133, 1522, 132, 1725]'),
#  Text(0.45454545454545453, 0.5833333333333334, 'gini = 0.134\nsamples = 1470\nvalue = [7, 6, 86, 1, 1365, 0, 5]'),
#  Text(0.6363636363636364, 0.5833333333333334, 'X[0] <= 0.255\ngini = 0.751\nsamples = 4831\nvalue = [1051, 409, 1230, 132, 157, 132, 1720]'),
#  Text(0.5454545454545454, 0.4166666666666667, 'gini = 0.328\nsamples = 2083\nvalue = [43, 0, 8, 132, 80, 125, 1695]'),
#  Text(0.7272727272727273, 0.4166666666666667, 'X[10] <= 0.173\ngini = 0.645\nsamples = 2748\nvalue = [1008, 409, 1222, 0, 77, 7, 25]'),
#  Text(0.6363636363636364, 0.25, 'gini = 0.005\nsamples = 410\nvalue = [1, 409, 0, 0, 0, 0, 0]'),
#  Text(0.8181818181818182, 0.25, 'X[12] <= 0.354\ngini = 0.54\nsamples = 2338\nvalue = [1007, 0, 1222, 0, 77, 7, 25]'),
#  Text(0.7272727272727273, 0.08333333333333333, 'gini = 0.387\nsamples = 1426\nvalue = [238, 0, 1088, 0, 76, 0, 24]'),
#  Text(0.9090909090909091, 0.08333333333333333, 'gini = 0.267\nsamples = 912\nvalue = [769, 0, 134, 0, 1, 7, 1]')]

# %%
print(classification_report(y_test, clf4.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.70      0.75       262
#            1       1.00      0.99      1.00       107
#            2       0.76      0.80      0.78       313
#            3       0.88      0.91      0.89       711
#            4       0.93      0.90      0.92       397
#            5       0.86      0.89      0.88       403
#            6       0.83      0.83      0.83       530
#
#     accuracy                           0.86      2723
#    macro avg       0.87      0.86      0.86      2723
# weighted avg       0.86      0.86      0.86      2723

# %%
fn=["Perimeter","MajorAxisLength","MinorAxisLength","Eccentricity","ConvexArea","EquivDiameter","Extent","Solidity","roundness","Compactness","ShapeFactor1","ShapeFactor2","ShapeFactor3","ShapeFactor4"]
cn=["SEKER","BARBUNYA","BOMBAY","CALI","HOROZ","SIRA","DERMASON"]
plt.figure()
tree.plot_tree(clf4, feature_names = fn,class_names=cn, filled=True)
plt.savefig('tree1.pdf')

# %%
clf4.score(x_train,y_train)
# Out:
# 0.8595701689933872

# %%
clf4.score(x_test,y_test)
# Out:
# 0.8604480352552332
